# %% [markdown]
# ### Two-Stream Encoder-Decoder Network for Localizing Image Forgeries
# #### Demo by Aniruddha Mazumdar

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read and Display the Input Image

# %%
filename = './sample_images/cover_73_sample.png'
img = imread(filename)
plt.imshow(img, cmap='gray')
# Out:
# /home/aniruddha-spina/anaconda3/envs/spina_conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.

# %%
filename
# Out:
# './sample_images/cover_73_sample.png'

# %% [markdown]
# ### Run the Inference Code

# %%
# !python encoder_decoder_train_2_decoder_Synthetic_NIST_Test_tf.py --input_image './sample_images/splicing-08.png' --output_filename './sample_images/splicing-08'
# Out:
# /home/aniruddha-spina/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aniruddha-spina/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aniruddha-spina/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ### Display the Input Image and Predicted Output

# %%
filename_input = './sample_images/NC2016_0211_sample.png'  ## Input Filename
input_img1 = imread(filename_input)

filename_input_gt_mask = './sample_images/NC2016_0211_sample_gt_mask.png'  ## Input Filename
input_gt_mask1 = imread(filename_input_gt_mask)

filename_output = './sample_images/NC2016_0211_sample_predicted_binary_mask.png'
pred_img1 = imread(filename_output)


filename_input = './sample_images/cover_73_sample.png'  ## Input Filename
input_img2 = imread(filename_input)

filename_input_gt_mask = './sample_images/cover_73_sample_gt_mask.png'  ## Input Filename
input_gt_mask2 = imread(filename_input_gt_mask)

filename_output = './sample_images/cover_73_predicted_binary_mask.png'
pred_img2 = imread(filename_output)


filename_input = './sample_images/splicing-08.png'  ## Input Filename
input_img3 = imread(filename_input)

filename_input_gt_mask = './sample_images/splicing-08_gt_mask.png'  ## Input Filename
input_gt_mask3 = imread(filename_input_gt_mask)

filename_output = './sample_images/splicing-08_predicted_binary_mask.png'
pred_img3 = imread(filename_output)





###############  Display the output  ########################################

fig = plt.figure(frameon=False, figsize=(15, 7), dpi=200)


fig.add_subplot(331)
plt.imshow(input_img1, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(332)
plt.imshow(input_gt_mask1, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(333)
plt.imshow(pred_img1, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')


fig.add_subplot(334)
plt.imshow(input_img2, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(335)
plt.imshow(input_gt_mask2, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(336)
plt.imshow(pred_img2, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')

fig.add_subplot(337)
plt.imshow(input_img3, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(338)
plt.imshow(input_gt_mask3, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(339)
plt.imshow(pred_img3, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')

#############################################################################
# Out:
# /home/aniruddha-spina/anaconda3/envs/spina_conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#
# /home/aniruddha-spina/anaconda3/envs/spina_conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   """
# /home/aniruddha-spina/anaconda3/envs/spina_conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#
# /home/aniruddha-spina/anaconda3/envs/spina_conda/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning:     `imread` is deprecated!
# ...
